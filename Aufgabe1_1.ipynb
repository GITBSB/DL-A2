# %% [markdown]
# <h3> Aufgabe 1a: Durchführung explorativer Datenanalyse </h3>
# <h3>Einbinden von Packages </h3>
# Pakete Pandas (Datenanalyse Tabelle) und Numpy (mehrdimensionale Arrays) für die Datenanalyse importieren

# %%
import pandas as pd
import numpy as np
np.__version__, pd.__version__
# Out:
# ('1.18.5', '1.0.5')

# %% [markdown]
# <h3> Einlesen der Daten </h3>
# Daten laden, import in pandas dataframe

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
cols   =['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','TGT']
boston = pd.read_csv(url, sep =' ', skipinitialspace = True, header = None, names =cols, index_col = False)
dateDownloaded = !date
dateDownloaded
# Out:
# ['Aktuelles Datum: 01.11.2020 ', 'Geben Sie das neue Datum ein: (TT-MM-JJ) ']

# %% [markdown]
# <h3> Darstellung Pandas DataFrame </h3>
# Daten anzeigen

# %%
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT   TGT
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# CRIM = Kriminalitätsrate, ZN= Anteil von Wohnbauland, INDUS= Anteil der nicht für den Einzelhandel bestimmten Geschäftsflächen pro Stadt, CHAS= Charles River Dummy-Variable, NOX= Konzentration von Stickstoffoxiden, RM= durchschnittliche Anzahl von Zimmern pro Wohnung, AGE= Anteil der vor 1940 gebauten Eigentumswohnungen, DIS= gewichtete Entfernungen zu fünf Bostoner Arbeitszentren, RAD= Index der Zugänglichkeit zu radialen Autobahnen, TAX= Vollwertiger Vermögenssteuersatz 10000, PTRATIO= Schüler-Lehrer-Verhältnis nach Stadt, B= Anzahl der Dunkelhäutigen pro Stadt, LSTAT= niedrigerer Status der Bevölkerung

# %% [markdown]
# Kürze Darstellung (Nur die ersten 5 Einträge)

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT   TGT
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Anzahl der Reihen und Spalten darstellen lassen.

# %%
np.shape(boston)
# Out:
# (506, 14)

# %% [markdown]
# Anzeigen der Spaltennamen

# %%
boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'TGT'],
#       dtype='object')

# %% [markdown]
# Datentypen der Variablen

# %%
boston.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# TGT        float64
# dtype: object

# %% [markdown]
# <h3> Aufbereitung des Datensatzes </h3>

# %% [markdown]
# Überprüfen, ob NAN vorhanden sind

# %%
boston.isna().any()
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# TGT        False
# dtype: bool

# %% [markdown]
# Überprüfen, ob doppelte Einträge vorhanden sind

# %%
boston.duplicated().any()
# Out:
# False

# %% [markdown]
# Keine Duplikate vorhanden.

# %% [markdown]
# <h3> Explorative Statistiken </h3>

# %% [markdown]
# Statistische Beschreibungen der Variablen

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Darstellung Streumatrix

# %%
pd.plotting.scatter_matrix(boston, figsize=(14,14), marker='o');

# %% [markdown]
# Darstellung der Korrelation

# %%
boston[cols].corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# <h3> Aufgabe 1b: Beantwortung der Fragen </h3>
# <h4> Welche Variablen sind kategorisch? </h4>
#    - CHAS
#    - RAD
# <h4> Welche der Variablen eignen sich gut zur Vorhersage des Hauspreises und warum? </h4>
#    - RM Positive Korrelation
#    - LSTAT Negative Korrelatation
# <h4> Welche dieser Variablen sind miteinander korreliert? </h4>
#
#    - INDUS + NOX (0.76)
#
#    - NOX + DIS (-0.769)
#
#    - CRIM + RAD (0.625)
#
#    - ZN + DIS (0.664)
#
#    - RAD + TAX (0.910)
#
#    - DIS + RAD (-0.769)
#
#    - AGE + DIS (-0.769)
# <h4> Welche sind daher Kandidaten,die man evtl. weglassen könnte? </h4>
#    - CHAS

# %% [markdown]
# <h3> Aufgabe 1c: Dokumentation der eingesetzten Systemkonfiguration und Paketversionen </h3>

# %%
# %reload_ext version_information

# %%
pip install version_information
# Out:
# ...
#   Created wheel for version-information: filename=version_information-1.0.3-cp36-none-any.whl size=3881 sha256=7f53162d27b9e16a7429e09f630ddb4d74929f943e6b4af07a2479b59ffaf88e
#   Stored in directory: /root/.cache/pip/wheels/1f/4c/b3/1976ac11dbd802723b564de1acaa453a72c36c95827e576321
# Successfully built version-information
# ...

# %%
# %version_information
# Out:
# Software versions
# Python 3.6.9 64bit [GCC 8.4.0]
# IPython 5.5.0
# OS Linux 4.19.112+ x86_64 with Ubuntu 18.04 bionic
# Sun Nov 01 20:02:35 2020 UTC

# %%
# %version_information numpy, pandas
# Out:
# Software versions
# Python 3.6.9 64bit [GCC 8.4.0]
# IPython 5.5.0
# OS Linux 4.19.112+ x86_64 with Ubuntu 18.04 bionic
# numpy 1.18.5
# pandas 1.1.3
# Sun Nov 01 20:02:44 2020 UTC
